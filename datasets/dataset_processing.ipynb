# %%
import pandas as pd
# Load the dataset
data = pd.read_csv('new_spam.csv')
data.drop_duplicates(inplace=True)

# Count the number of 'ham' and 'spam' entries
ham_count = data[data['Category'] == 'ham'].shape[0]
spam_count = data[data['Category'] == 'spam'].shape[0]

# Check for duplicates
duplicate_count = data.duplicated().sum()

# # Check for non-English entries
# def is_english(text):
#     try:
#         text.encode(encoding='utf-8').decode('ascii')
#     except UnicodeDecodeError:
#         return False
#     else:
#         return True

# non_english_count = data['Message'].apply(lambda x: not is_english(x)).sum()

data.to_csv('cleaned_spam.csv', index=False)
# Print the results
print(f"Number of 'ham' messages: {ham_count}")
print(f"Number of 'spam' messages: {spam_count}")
print(f"Number of duplicate messages: {duplicate_count}")
# print(f"Number of non-English messages: {non_english_count}")
# Out:
# Number of 'ham' messages: 4516
# Number of 'spam' messages: 3729
# Number of duplicate messages: 0

# %%
import pandas as pd
import re

# Load the dataset
df = pd.read_csv('new_spam.csv')

def clean_text(text):
    if pd.isna(text) or not isinstance(text, str):
        return ""  # Return empty string for NaN or non-string values

    # Remove only the "Subject:" phrase from the text
    text = re.sub(r'\bSubject:\s*', '', text)
    
    # Keep English letters, numbers, punctuation, and whitespace
    text = re.sub(r'[^\w\s,.!?;:()-]', '', text)
    
    # Replace multiple spaces with a single space
    text = re.sub(r'\s+', ' ', text)
    
    # Strip leading and trailing whitespace
    return text.strip()

# Apply the cleaning function to the 'Message' column
df['Message'] = df['Message'].apply(clean_text)

# Save the cleaned data
df.to_csv('cleaned_spam.csv', index=False)

# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold

# Load the dataset
data = pd.read_csv('new_spam.csv')

# Initialize StratifiedKFold to split data into, e.g., 5 equal parts
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Split the data while maintaining the same proportion of categories
for fold, (train_idx, test_idx) in enumerate(skf.split(data, data['Category'])):
    # Create a part of the dataset
    part = data.iloc[test_idx]
    
    # Save each part to a new CSV file
    part.to_csv(f'part_{fold+1}.csv', index=False)

    # Optionally, you can print out the proportion of 'ham' and 'spam' in each part
    print(f"Part {fold+1}:")
    print(part['Category'].value_counts(normalize=True))
# Out:
# Part 1:
# Category
# ham     0.547836
# spam    0.452164
# Name: proportion, dtype: float64
# Part 2:
# Category
# ham               0.547472
# spam              0.452164
# {"mode":"full"    0.000364
# Name: proportion, dtype: float64
# Part 3:
# Category
# ham     0.547671
# spam    0.452329
# Name: proportion, dtype: float64
# c:\Users\kingc\anaconda3\envs\federated-knn\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(

# %%
data.dropna(subset=['Message'], inplace=True)  # Ensure no NaN entries in 'Message' column
data.to_csv('new_spam.csv', index=False)  # Save the cleaned data to a new CSV file

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kingc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kingc\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\kingc\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\kingc\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kingc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import pandas as pd
import random
import nltk
from nltk.corpus import wordnet, stopwords
from nltk.tokenize import word_tokenize


# Set up the stopwords
stop_words = set(stopwords.words('english'))

def get_synonyms(word):
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonym = lemma.name().replace('_', ' ')
            if synonym != word:
                synonyms.add(synonym)
    return list(synonyms)

def synonym_replacement(sentence, n):
    words = word_tokenize(sentence)
    non_stop_words = [word for word in words if word not in stop_words]
    random_words = random.sample(non_stop_words, min(n, len(non_stop_words)))
    new_words = words[:]
    for word in random_words:
        synonyms = get_synonyms(word)
        if synonyms:
            new_word = random.choice(synonyms)
            new_words = [new_word if w == word else w for w in new_words]
    return ' '.join(new_words)

def random_insertion(sentence, n, max_attempts=10):
    words = word_tokenize(sentence)
    for _ in range(n):
        attempts = 0
        inserted = False
        while not inserted and attempts < max_attempts:
            word = random.choice(words)
            if word not in stop_words:
                synonyms = get_synonyms(word)
                if synonyms:
                    new_word = random.choice(synonyms)
                    position = random.randint(0, len(words))
                    words.insert(position, new_word)
                    inserted = True
            attempts += 1
        if attempts == max_attempts:
            print(f"Failed to find a synonym for insertion after {max_attempts} attempts.")
    return ' '.join(words)


def random_swap(sentence, n):
    words = word_tokenize(sentence)
    length = len(words)
    if length < 2:
        print("Not enough words to perform swap.")
        return sentence  # Return the original sentence if not enough words to swap
    for _ in range(n):
        idx1, idx2 = random.sample(range(length), 2)
        words[idx1], words[idx2] = words[idx2], words[idx1]
    return ' '.join(words)


def random_deletion(sentence, p):
    words = word_tokenize(sentence)
    new_words = [word for word in words if random.random() > p]
    return ' '.join(new_words)

# Load the dataset
print("Loading dataset...")
df = pd.read_csv('new_spam.csv')

# Assuming the dataset is initially balanced
augment_funcs = [synonym_replacement, random_insertion, random_swap, random_deletion]
augmented_rows = []

print("Starting data augmentation...")
for index, row in df.iterrows():
    category, message = row['Category'], row['Message']
    for func in augment_funcs:
        if func in [synonym_replacement, random_insertion]:
            new_message = func(message, 2)
        elif func == random_swap:
            new_message = func(message, 2)
        elif func == random_deletion:
            new_message = func(message, 0.1)
        augmented_rows.append([category, new_message])
    print(f"Augmented row {index + 1}/{len(df)}")

# Create a DataFrame from the augmented rows and concatenate it with the original DataFrame
augmented_df = pd.DataFrame(augmented_rows, columns=['Category', 'Message'])
df_augmented = pd.concat([df, augmented_df]).drop_duplicates(subset=['Message'])

# Shuffle the DataFrame
df_augmented = df_augmented.sample(frac=1).reset_index(drop=True)

# Optionally, save the augmented DataFrame to a new CSV file
df_augmented.to_csv('augmented_spam.csv', index=False)

print("Augmentation complete. The augmented dataset has been saved.")
# Out:
# Loading dataset...
# Starting data augmentation...
# Augmented row 1/8245
# Augmented row 2/8245
# Augmented row 3/8245
# Augmented row 4/8245
# Augmented row 5/8245
# Augmented row 6/8245
# Augmented row 7/8245
# Augmented row 8/8245
# Augmented row 9/8245
# Augmented row 10/8245
# Augmented row 11/8245
# Augmented row 12/8245
# Augmented row 13/8245
# Augmented row 14/8245
# Augmented row 15/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 16/8245
# Augmented row 17/8245
# Augmented row 18/8245
# Augmented row 19/8245
# Augmented row 20/8245
# Augmented row 21/8245
# Augmented row 22/8245
# Augmented row 23/8245
# Augmented row 24/8245
# Augmented row 25/8245
# Augmented row 26/8245
# Augmented row 27/8245
# Augmented row 28/8245
# Augmented row 29/8245
# Augmented row 30/8245
# Augmented row 31/8245
# Augmented row 32/8245
# Augmented row 33/8245
# Augmented row 34/8245
# Augmented row 35/8245
# Augmented row 36/8245
# Augmented row 37/8245
# Augmented row 38/8245
# Augmented row 39/8245
# Augmented row 40/8245
# Augmented row 41/8245
# Augmented row 42/8245
# Augmented row 43/8245
# Augmented row 44/8245
# Augmented row 45/8245
# Augmented row 46/8245
# Augmented row 47/8245
# Augmented row 48/8245
# Augmented row 49/8245
# Augmented row 50/8245
# Augmented row 51/8245
# Augmented row 52/8245
# Augmented row 53/8245
# Augmented row 54/8245
# Augmented row 55/8245
# Augmented row 56/8245
# Augmented row 57/8245
# Augmented row 58/8245
# Augmented row 59/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 60/8245
# Augmented row 61/8245
# Augmented row 62/8245
# Augmented row 63/8245
# Augmented row 64/8245
# Augmented row 65/8245
# Augmented row 66/8245
# Augmented row 67/8245
# Augmented row 68/8245
# Augmented row 69/8245
# Augmented row 70/8245
# Augmented row 71/8245
# Augmented row 72/8245
# Augmented row 73/8245
# Augmented row 74/8245
# Augmented row 75/8245
# Augmented row 76/8245
# Augmented row 77/8245
# Augmented row 78/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 79/8245
# Augmented row 80/8245
# Augmented row 81/8245
# Augmented row 82/8245
# Augmented row 83/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 84/8245
# Augmented row 85/8245
# Augmented row 86/8245
# Augmented row 87/8245
# Augmented row 88/8245
# Augmented row 89/8245
# Augmented row 90/8245
# Augmented row 91/8245
# Augmented row 92/8245
# Augmented row 93/8245
# Augmented row 94/8245
# Augmented row 95/8245
# Augmented row 96/8245
# Augmented row 97/8245
# Augmented row 98/8245
# Augmented row 99/8245
# Augmented row 100/8245
# Augmented row 101/8245
# Augmented row 102/8245
# Augmented row 103/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 104/8245
# Augmented row 105/8245
# Augmented row 106/8245
# Augmented row 107/8245
# Augmented row 108/8245
# Augmented row 109/8245
# Augmented row 110/8245
# Augmented row 111/8245
# Augmented row 112/8245
# Augmented row 113/8245
# Augmented row 114/8245
# Augmented row 115/8245
# Augmented row 116/8245
# Augmented row 117/8245
# Augmented row 118/8245
# Augmented row 119/8245
# Augmented row 120/8245
# Augmented row 121/8245
# Augmented row 122/8245
# Augmented row 123/8245
# Augmented row 124/8245
# Augmented row 125/8245
# Augmented row 126/8245
# Augmented row 127/8245
# Augmented row 128/8245
# Augmented row 129/8245
# Augmented row 130/8245
# Augmented row 131/8245
# Augmented row 132/8245
# Augmented row 133/8245
# Augmented row 134/8245
# Augmented row 135/8245
# Augmented row 136/8245
# Augmented row 137/8245
# Augmented row 138/8245
# Augmented row 139/8245
# Augmented row 140/8245
# Augmented row 141/8245
# Augmented row 142/8245
# Augmented row 143/8245
# Augmented row 144/8245
# Augmented row 145/8245
# Augmented row 146/8245
# Augmented row 147/8245
# Augmented row 148/8245
# Augmented row 149/8245
# Augmented row 150/8245
# Augmented row 151/8245
# Augmented row 152/8245
# Augmented row 153/8245
# Augmented row 154/8245
# Augmented row 155/8245
# Augmented row 156/8245
# Augmented row 157/8245
# Augmented row 158/8245
# Augmented row 159/8245
# Augmented row 160/8245
# Augmented row 161/8245
# Augmented row 162/8245
# Augmented row 163/8245
# Augmented row 164/8245
# Augmented row 165/8245
# Augmented row 166/8245
# Augmented row 167/8245
# Augmented row 168/8245
# Augmented row 169/8245
# Augmented row 170/8245
# Augmented row 171/8245
# Augmented row 172/8245
# Augmented row 173/8245
# Augmented row 174/8245
# Augmented row 175/8245
# Augmented row 176/8245
# Augmented row 177/8245
# Augmented row 178/8245
# Augmented row 179/8245
# Augmented row 180/8245
# Augmented row 181/8245
# Augmented row 182/8245
# Augmented row 183/8245
# Augmented row 184/8245
# Augmented row 185/8245
# Augmented row 186/8245
# Augmented row 187/8245
# Augmented row 188/8245
# Augmented row 189/8245
# Augmented row 190/8245
# Augmented row 191/8245
# Augmented row 192/8245
# Augmented row 193/8245
# Augmented row 194/8245
# Augmented row 195/8245
# Augmented row 196/8245
# Augmented row 197/8245
# Augmented row 198/8245
# Augmented row 199/8245
# Augmented row 200/8245
# Augmented row 201/8245
# Augmented row 202/8245
# Augmented row 203/8245
# Augmented row 204/8245
# Augmented row 205/8245
# Augmented row 206/8245
# Augmented row 207/8245
# Augmented row 208/8245
# Augmented row 209/8245
# Augmented row 210/8245
# Augmented row 211/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 212/8245
# Augmented row 213/8245
# Augmented row 214/8245
# Augmented row 215/8245
# Augmented row 216/8245
# Augmented row 217/8245
# Augmented row 218/8245
# Augmented row 219/8245
# Augmented row 220/8245
# Augmented row 221/8245
# Augmented row 222/8245
# Augmented row 223/8245
# Augmented row 224/8245
# Augmented row 225/8245
# Augmented row 226/8245
# Augmented row 227/8245
# Augmented row 228/8245
# Augmented row 229/8245
# Augmented row 230/8245
# Augmented row 231/8245
# Augmented row 232/8245
# Augmented row 233/8245
# Augmented row 234/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 235/8245
# Augmented row 236/8245
# Augmented row 237/8245
# Augmented row 238/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 239/8245
# Augmented row 240/8245
# Augmented row 241/8245
# Augmented row 242/8245
# Augmented row 243/8245
# Augmented row 244/8245
# Augmented row 245/8245
# Augmented row 246/8245
# Augmented row 247/8245
# Augmented row 248/8245
# Augmented row 249/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 250/8245
# Augmented row 251/8245
# Augmented row 252/8245
# Augmented row 253/8245
# Augmented row 254/8245
# Augmented row 255/8245
# Augmented row 256/8245
# Augmented row 257/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Not enough words to perform swap.
# Augmented row 258/8245
# Augmented row 259/8245
# Augmented row 260/8245
# Augmented row 261/8245
# Augmented row 262/8245
# Augmented row 263/8245
# Augmented row 264/8245
# Augmented row 265/8245
# Augmented row 266/8245
# Augmented row 267/8245
# Augmented row 268/8245
# Augmented row 269/8245
# Augmented row 270/8245
# Augmented row 271/8245
# Augmented row 272/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 273/8245
# Augmented row 274/8245
# Augmented row 275/8245
# Augmented row 276/8245
# Augmented row 277/8245
# Augmented row 278/8245
# Augmented row 279/8245
# Augmented row 280/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 281/8245
# Augmented row 282/8245
# Augmented row 283/8245
# Augmented row 284/8245
# Augmented row 285/8245
# Augmented row 286/8245
# Augmented row 287/8245
# Augmented row 288/8245
# Augmented row 289/8245
# Augmented row 290/8245
# Augmented row 291/8245
# Augmented row 292/8245
# Augmented row 293/8245
# Augmented row 294/8245
# Augmented row 295/8245
# Augmented row 296/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 297/8245
# Augmented row 298/8245
# Augmented row 299/8245
# Augmented row 300/8245
# Augmented row 301/8245
# Augmented row 302/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 303/8245
# Augmented row 304/8245
# Augmented row 305/8245
# Augmented row 306/8245
# Augmented row 307/8245
# Augmented row 308/8245
# Augmented row 309/8245
# Augmented row 310/8245
# Augmented row 311/8245
# Augmented row 312/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 313/8245
# Augmented row 314/8245
# Augmented row 315/8245
# Augmented row 316/8245
# Augmented row 317/8245
# Augmented row 318/8245
# Augmented row 319/8245
# Augmented row 320/8245
# Augmented row 321/8245
# Augmented row 322/8245
# Augmented row 323/8245
# Augmented row 324/8245
# Augmented row 325/8245
# Augmented row 326/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 327/8245
# Augmented row 328/8245
# Augmented row 329/8245
# Augmented row 330/8245
# Augmented row 331/8245
# Augmented row 332/8245
# Augmented row 333/8245
# Augmented row 334/8245
# Augmented row 335/8245
# Augmented row 336/8245
# Augmented row 337/8245
# Augmented row 338/8245
# Augmented row 339/8245
# Augmented row 340/8245
# Augmented row 341/8245
# Augmented row 342/8245
# Augmented row 343/8245
# Augmented row 344/8245
# Augmented row 345/8245
# Augmented row 346/8245
# Augmented row 347/8245
# Augmented row 348/8245
# Augmented row 349/8245
# Augmented row 350/8245
# Augmented row 351/8245
# Augmented row 352/8245
# Augmented row 353/8245
# Augmented row 354/8245
# Augmented row 355/8245
# Augmented row 356/8245
# Augmented row 357/8245
# Augmented row 358/8245
# Augmented row 359/8245
# Augmented row 360/8245
# Augmented row 361/8245
# Augmented row 362/8245
# Augmented row 363/8245
# Augmented row 364/8245
# Augmented row 365/8245
# Augmented row 366/8245
# Augmented row 367/8245
# Augmented row 368/8245
# Augmented row 369/8245
# Augmented row 370/8245
# Augmented row 371/8245
# Augmented row 372/8245
# Augmented row 373/8245
# Augmented row 374/8245
# Augmented row 375/8245
# Augmented row 376/8245
# Augmented row 377/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 378/8245
# Augmented row 379/8245
# Augmented row 380/8245
# Augmented row 381/8245
# Augmented row 382/8245
# Augmented row 383/8245
# Augmented row 384/8245
# Augmented row 385/8245
# Augmented row 386/8245
# Augmented row 387/8245
# Augmented row 388/8245
# Augmented row 389/8245
# Augmented row 390/8245
# Augmented row 391/8245
# Augmented row 392/8245
# Augmented row 393/8245
# Augmented row 394/8245
# Augmented row 395/8245
# Augmented row 396/8245
# Augmented row 397/8245
# Augmented row 398/8245
# Augmented row 399/8245
# Augmented row 400/8245
# Augmented row 401/8245
# Augmented row 402/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 403/8245
# Augmented row 404/8245
# Augmented row 405/8245
# Augmented row 406/8245
# Augmented row 407/8245
# Augmented row 408/8245
# Augmented row 409/8245
# Augmented row 410/8245
# Augmented row 411/8245
# Augmented row 412/8245
# Augmented row 413/8245
# Augmented row 414/8245
# Augmented row 415/8245
# Augmented row 416/8245
# Augmented row 417/8245
# Augmented row 418/8245
# Augmented row 419/8245
# Augmented row 420/8245
# Augmented row 421/8245
# Augmented row 422/8245
# Augmented row 423/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 424/8245
# Augmented row 425/8245
# Augmented row 426/8245
# Augmented row 427/8245
# Augmented row 428/8245
# Augmented row 429/8245
# Augmented row 430/8245
# Augmented row 431/8245
# Augmented row 432/8245
# Augmented row 433/8245
# Augmented row 434/8245
# Augmented row 435/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 436/8245
# Augmented row 437/8245
# Augmented row 438/8245
# Augmented row 439/8245
# Augmented row 440/8245
# Augmented row 441/8245
# Augmented row 442/8245
# Augmented row 443/8245
# Augmented row 444/8245
# Augmented row 445/8245
# Augmented row 446/8245
# Augmented row 447/8245
# Augmented row 448/8245
# Augmented row 449/8245
# Augmented row 450/8245
# Augmented row 451/8245
# Augmented row 452/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 453/8245
# Augmented row 454/8245
# Augmented row 455/8245
# Augmented row 456/8245
# Augmented row 457/8245
# Augmented row 458/8245
# Augmented row 459/8245
# Augmented row 460/8245
# Augmented row 461/8245
# Augmented row 462/8245
# Augmented row 463/8245
# Augmented row 464/8245
# Augmented row 465/8245
# Augmented row 466/8245
# Augmented row 467/8245
# Augmented row 468/8245
# Augmented row 469/8245
# Augmented row 470/8245
# Augmented row 471/8245
# Augmented row 472/8245
# Augmented row 473/8245
# Augmented row 474/8245
# Augmented row 475/8245
# Augmented row 476/8245
# Augmented row 477/8245
# Augmented row 478/8245
# Augmented row 479/8245
# Augmented row 480/8245
# Augmented row 481/8245
# Augmented row 482/8245
# Augmented row 483/8245
# Augmented row 484/8245
# Augmented row 485/8245
# Augmented row 486/8245
# Augmented row 487/8245
# Augmented row 488/8245
# Augmented row 489/8245
# Augmented row 490/8245
# Augmented row 491/8245
# Augmented row 492/8245
# Augmented row 493/8245
# Augmented row 494/8245
# Augmented row 495/8245
# Augmented row 496/8245
# Augmented row 497/8245
# Augmented row 498/8245
# Augmented row 499/8245
# Augmented row 500/8245
# Augmented row 501/8245
# Augmented row 502/8245
# Augmented row 503/8245
# Augmented row 504/8245
# Augmented row 505/8245
# Augmented row 506/8245
# Augmented row 507/8245
# Augmented row 508/8245
# Augmented row 509/8245
# Augmented row 510/8245
# Augmented row 511/8245
# Augmented row 512/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 513/8245
# Augmented row 514/8245
# Augmented row 515/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 516/8245
# Augmented row 517/8245
# Augmented row 518/8245
# Augmented row 519/8245
# Augmented row 520/8245
# Augmented row 521/8245
# Augmented row 522/8245
# Augmented row 523/8245
# Augmented row 524/8245
# Augmented row 525/8245
# Augmented row 526/8245
# Augmented row 527/8245
# Augmented row 528/8245
# Augmented row 529/8245
# Augmented row 530/8245
# Augmented row 531/8245
# Augmented row 532/8245
# Augmented row 533/8245
# Augmented row 534/8245
# Augmented row 535/8245
# Augmented row 536/8245
# Augmented row 537/8245
# Augmented row 538/8245
# Augmented row 539/8245
# Augmented row 540/8245
# Augmented row 541/8245
# Augmented row 542/8245
# Augmented row 543/8245
# Augmented row 544/8245
# Augmented row 545/8245
# Augmented row 546/8245
# Augmented row 547/8245
# Augmented row 548/8245
# Augmented row 549/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 550/8245
# Augmented row 551/8245
# Augmented row 552/8245
# Augmented row 553/8245
# Augmented row 554/8245
# Augmented row 555/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 556/8245
# Augmented row 557/8245
# Augmented row 558/8245
# Augmented row 559/8245
# Augmented row 560/8245
# Augmented row 561/8245
# Augmented row 562/8245
# Augmented row 563/8245
# Augmented row 564/8245
# Augmented row 565/8245
# Augmented row 566/8245
# Augmented row 567/8245
# Augmented row 568/8245
# Augmented row 569/8245
# Augmented row 570/8245
# Augmented row 571/8245
# Augmented row 572/8245
# Augmented row 573/8245
# Augmented row 574/8245
# Augmented row 575/8245
# Augmented row 576/8245
# Augmented row 577/8245
# Augmented row 578/8245
# Augmented row 579/8245
# Augmented row 580/8245
# Augmented row 581/8245
# Augmented row 582/8245
# Augmented row 583/8245
# Augmented row 584/8245
# Augmented row 585/8245
# Augmented row 586/8245
# Augmented row 587/8245
# Augmented row 588/8245
# Augmented row 589/8245
# Augmented row 590/8245
# Augmented row 591/8245
# Augmented row 592/8245
# Augmented row 593/8245
# Augmented row 594/8245
# Augmented row 595/8245
# Augmented row 596/8245
# Augmented row 597/8245
# Augmented row 598/8245
# Augmented row 599/8245
# Augmented row 600/8245
# Augmented row 601/8245
# Augmented row 602/8245
# Augmented row 603/8245
# Augmented row 604/8245
# Augmented row 605/8245
# Augmented row 606/8245
# Augmented row 607/8245
# Augmented row 608/8245
# Augmented row 609/8245
# Augmented row 610/8245
# Augmented row 611/8245
# Augmented row 612/8245
# Augmented row 613/8245
# Augmented row 614/8245
# Augmented row 615/8245
# Augmented row 616/8245
# Augmented row 617/8245
# Augmented row 618/8245
# Augmented row 619/8245
# Augmented row 620/8245
# Augmented row 621/8245
# Augmented row 622/8245
# Augmented row 623/8245
# Augmented row 624/8245
# Augmented row 625/8245
# Augmented row 626/8245
# Augmented row 627/8245
# Augmented row 628/8245
# Augmented row 629/8245
# Augmented row 630/8245
# Augmented row 631/8245
# Augmented row 632/8245
# Augmented row 633/8245
# Augmented row 634/8245
# Augmented row 635/8245
# Augmented row 636/8245
# Augmented row 637/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 638/8245
# Augmented row 639/8245
# Augmented row 640/8245
# Augmented row 641/8245
# Augmented row 642/8245
# Augmented row 643/8245
# Augmented row 644/8245
# Augmented row 645/8245
# Augmented row 646/8245
# Augmented row 647/8245
# Augmented row 648/8245
# Augmented row 649/8245
# Augmented row 650/8245
# Augmented row 651/8245
# Augmented row 652/8245
# Augmented row 653/8245
# Augmented row 654/8245
# Augmented row 655/8245
# Augmented row 656/8245
# Augmented row 657/8245
# Augmented row 658/8245
# Augmented row 659/8245
# Augmented row 660/8245
# Augmented row 661/8245
# Augmented row 662/8245
# Augmented row 663/8245
# Augmented row 664/8245
# Augmented row 665/8245
# Augmented row 666/8245
# Augmented row 667/8245
# Augmented row 668/8245
# Augmented row 669/8245
# Augmented row 670/8245
# Augmented row 671/8245
# Augmented row 672/8245
# Augmented row 673/8245
# Augmented row 674/8245
# Augmented row 675/8245
# Augmented row 676/8245
# Augmented row 677/8245
# Augmented row 678/8245
# Augmented row 679/8245
# Augmented row 680/8245
# Augmented row 681/8245
# Augmented row 682/8245
# Augmented row 683/8245
# Augmented row 684/8245
# Augmented row 685/8245
# Augmented row 686/8245
# Augmented row 687/8245
# Augmented row 688/8245
# Augmented row 689/8245
# Augmented row 690/8245
# Augmented row 691/8245
# Augmented row 692/8245
# Augmented row 693/8245
# Augmented row 694/8245
# Augmented row 695/8245
# Augmented row 696/8245
# Augmented row 697/8245
# Augmented row 698/8245
# Augmented row 699/8245
# Augmented row 700/8245
# Augmented row 701/8245
# Augmented row 702/8245
# Augmented row 703/8245
# Augmented row 704/8245
# Augmented row 705/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 706/8245
# Augmented row 707/8245
# Augmented row 708/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 709/8245
# Augmented row 710/8245
# Augmented row 711/8245
# Augmented row 712/8245
# Augmented row 713/8245
# Augmented row 714/8245
# Augmented row 715/8245
# Augmented row 716/8245
# Augmented row 717/8245
# Augmented row 718/8245
# Augmented row 719/8245
# Augmented row 720/8245
# Augmented row 721/8245
# Augmented row 722/8245
# Augmented row 723/8245
# Augmented row 724/8245
# Augmented row 725/8245
# Augmented row 726/8245
# Augmented row 727/8245
# Augmented row 728/8245
# Augmented row 729/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 730/8245
# Augmented row 731/8245
# Augmented row 732/8245
# Augmented row 733/8245
# Augmented row 734/8245
# Augmented row 735/8245
# Augmented row 736/8245
# Augmented row 737/8245
# Augmented row 738/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 739/8245
# Augmented row 740/8245
# Augmented row 741/8245
# Augmented row 742/8245
# Augmented row 743/8245
# Augmented row 744/8245
# Augmented row 745/8245
# Augmented row 746/8245
# Augmented row 747/8245
# Augmented row 748/8245
# Augmented row 749/8245
# Augmented row 750/8245
# Augmented row 751/8245
# Augmented row 752/8245
# Augmented row 753/8245
# Augmented row 754/8245
# Augmented row 755/8245
# Augmented row 756/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 757/8245
# Augmented row 758/8245
# Augmented row 759/8245
# Augmented row 760/8245
# Augmented row 761/8245
# Augmented row 762/8245
# Augmented row 763/8245
# Augmented row 764/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 765/8245
# Augmented row 766/8245
# Augmented row 767/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 768/8245
# Augmented row 769/8245
# Augmented row 770/8245
# Augmented row 771/8245
# Augmented row 772/8245
# Augmented row 773/8245
# Augmented row 774/8245
# Augmented row 775/8245
# Augmented row 776/8245
# Augmented row 777/8245
# Augmented row 778/8245
# Augmented row 779/8245
# Augmented row 780/8245
# Augmented row 781/8245
# Augmented row 782/8245
# Augmented row 783/8245
# Augmented row 784/8245
# Augmented row 785/8245
# Augmented row 786/8245
# Augmented row 787/8245
# Augmented row 788/8245
# Augmented row 789/8245
# Augmented row 790/8245
# Augmented row 791/8245
# Augmented row 792/8245
# Augmented row 793/8245
# Augmented row 794/8245
# Augmented row 795/8245
# Augmented row 796/8245
# Augmented row 797/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 798/8245
# Augmented row 799/8245
# Augmented row 800/8245
# Augmented row 801/8245
# Augmented row 802/8245
# Augmented row 803/8245
# Augmented row 804/8245
# Augmented row 805/8245
# Augmented row 806/8245
# Augmented row 807/8245
# Augmented row 808/8245
# Augmented row 809/8245
# Augmented row 810/8245
# Augmented row 811/8245
# Augmented row 812/8245
# Augmented row 813/8245
# Augmented row 814/8245
# Augmented row 815/8245
# Augmented row 816/8245
# Augmented row 817/8245
# Augmented row 818/8245
# Augmented row 819/8245
# Augmented row 820/8245
# Augmented row 821/8245
# Augmented row 822/8245
# Augmented row 823/8245
# Augmented row 824/8245
# Augmented row 825/8245
# Augmented row 826/8245
# Augmented row 827/8245
# Augmented row 828/8245
# Augmented row 829/8245
# Augmented row 830/8245
# Augmented row 831/8245
# Augmented row 832/8245
# Augmented row 833/8245
# Augmented row 834/8245
# Augmented row 835/8245
# Augmented row 836/8245
# Augmented row 837/8245
# Augmented row 838/8245
# Augmented row 839/8245
# Augmented row 840/8245
# Augmented row 841/8245
# Augmented row 842/8245
# Augmented row 843/8245
# Augmented row 844/8245
# Augmented row 845/8245
# Augmented row 846/8245
# Augmented row 847/8245
# Augmented row 848/8245
# Augmented row 849/8245
# Augmented row 850/8245
# Augmented row 851/8245
# Augmented row 852/8245
# Augmented row 853/8245
# Augmented row 854/8245
# Augmented row 855/8245
# Augmented row 856/8245
# Augmented row 857/8245
# Augmented row 858/8245
# Augmented row 859/8245
# Augmented row 860/8245
# Augmented row 861/8245
# Augmented row 862/8245
# Augmented row 863/8245
# Augmented row 864/8245
# Augmented row 865/8245
# Augmented row 866/8245
# Augmented row 867/8245
# Augmented row 868/8245
# Augmented row 869/8245
# Augmented row 870/8245
# Augmented row 871/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 872/8245
# Augmented row 873/8245
# Augmented row 874/8245
# Augmented row 875/8245
# Augmented row 876/8245
# Augmented row 877/8245
# Augmented row 878/8245
# Augmented row 879/8245
# Augmented row 880/8245
# Augmented row 881/8245
# Augmented row 882/8245
# Augmented row 883/8245
# Augmented row 884/8245
# Augmented row 885/8245
# Augmented row 886/8245
# Augmented row 887/8245
# Augmented row 888/8245
# Augmented row 889/8245
# Augmented row 890/8245
# Augmented row 891/8245
# Augmented row 892/8245
# Augmented row 893/8245
# Augmented row 894/8245
# Augmented row 895/8245
# Augmented row 896/8245
# Augmented row 897/8245
# Augmented row 898/8245
# Augmented row 899/8245
# Augmented row 900/8245
# Augmented row 901/8245
# Augmented row 902/8245
# Augmented row 903/8245
# Augmented row 904/8245
# Augmented row 905/8245
# Augmented row 906/8245
# Augmented row 907/8245
# Augmented row 908/8245
# Augmented row 909/8245
# Augmented row 910/8245
# Augmented row 911/8245
# Augmented row 912/8245
# Augmented row 913/8245
# Augmented row 914/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 915/8245
# Augmented row 916/8245
# Augmented row 917/8245
# Augmented row 918/8245
# Augmented row 919/8245
# Augmented row 920/8245
# Augmented row 921/8245
# Augmented row 922/8245
# Augmented row 923/8245
# Augmented row 924/8245
# Augmented row 925/8245
# Augmented row 926/8245
# Augmented row 927/8245
# Augmented row 928/8245
# Augmented row 929/8245
# Augmented row 930/8245
# Augmented row 931/8245
# Augmented row 932/8245
# Augmented row 933/8245
# Augmented row 934/8245
# Augmented row 935/8245
# Augmented row 936/8245
# Augmented row 937/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 938/8245
# Augmented row 939/8245
# Augmented row 940/8245
# Augmented row 941/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 942/8245
# Augmented row 943/8245
# Augmented row 944/8245
# Augmented row 945/8245
# Augmented row 946/8245
# Augmented row 947/8245
# Augmented row 948/8245
# Augmented row 949/8245
# Augmented row 950/8245
# Augmented row 951/8245
# Augmented row 952/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 953/8245
# Augmented row 954/8245
# Augmented row 955/8245
# Augmented row 956/8245
# Augmented row 957/8245
# Augmented row 958/8245
# Augmented row 959/8245
# Augmented row 960/8245
# Augmented row 961/8245
# Augmented row 962/8245
# Augmented row 963/8245
# Augmented row 964/8245
# Augmented row 965/8245
# Augmented row 966/8245
# Augmented row 967/8245
# Augmented row 968/8245
# Augmented row 969/8245
# Augmented row 970/8245
# Augmented row 971/8245
# Augmented row 972/8245
# Augmented row 973/8245
# Augmented row 974/8245
# Augmented row 975/8245
# Augmented row 976/8245
# Augmented row 977/8245
# Augmented row 978/8245
# Augmented row 979/8245
# Augmented row 980/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 981/8245
# Augmented row 982/8245
# Augmented row 983/8245
# Augmented row 984/8245
# Augmented row 985/8245
# Augmented row 986/8245
# Augmented row 987/8245
# Augmented row 988/8245
# Augmented row 989/8245
# Augmented row 990/8245
# Augmented row 991/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 992/8245
# Augmented row 993/8245
# Augmented row 994/8245
# Augmented row 995/8245
# Augmented row 996/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 997/8245
# Augmented row 998/8245
# Augmented row 999/8245
# Augmented row 1000/8245
# Augmented row 1001/8245
# Augmented row 1002/8245
# Augmented row 1003/8245
# Augmented row 1004/8245
# Augmented row 1005/8245
# Augmented row 1006/8245
# Augmented row 1007/8245
# Augmented row 1008/8245
# Augmented row 1009/8245
# Augmented row 1010/8245
# Augmented row 1011/8245
# Augmented row 1012/8245
# Augmented row 1013/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1014/8245
# Augmented row 1015/8245
# Augmented row 1016/8245
# Augmented row 1017/8245
# Augmented row 1018/8245
# Augmented row 1019/8245
# Augmented row 1020/8245
# Augmented row 1021/8245
# Augmented row 1022/8245
# Augmented row 1023/8245
# Augmented row 1024/8245
# Augmented row 1025/8245
# Augmented row 1026/8245
# Augmented row 1027/8245
# Augmented row 1028/8245
# Augmented row 1029/8245
# Augmented row 1030/8245
# Augmented row 1031/8245
# Augmented row 1032/8245
# Augmented row 1033/8245
# Augmented row 1034/8245
# Augmented row 1035/8245
# Augmented row 1036/8245
# Augmented row 1037/8245
# Augmented row 1038/8245
# Augmented row 1039/8245
# Augmented row 1040/8245
# Augmented row 1041/8245
# Augmented row 1042/8245
# Augmented row 1043/8245
# Augmented row 1044/8245
# Augmented row 1045/8245
# Augmented row 1046/8245
# Augmented row 1047/8245
# Augmented row 1048/8245
# Augmented row 1049/8245
# Augmented row 1050/8245
# Augmented row 1051/8245
# Augmented row 1052/8245
# Augmented row 1053/8245
# Augmented row 1054/8245
# Augmented row 1055/8245
# Augmented row 1056/8245
# Augmented row 1057/8245
# Augmented row 1058/8245
# Augmented row 1059/8245
# Augmented row 1060/8245
# Augmented row 1061/8245
# Augmented row 1062/8245
# Augmented row 1063/8245
# Augmented row 1064/8245
# Augmented row 1065/8245
# Augmented row 1066/8245
# Augmented row 1067/8245
# Augmented row 1068/8245
# Augmented row 1069/8245
# Augmented row 1070/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1071/8245
# Augmented row 1072/8245
# Augmented row 1073/8245
# Augmented row 1074/8245
# Augmented row 1075/8245
# Augmented row 1076/8245
# Augmented row 1077/8245
# Augmented row 1078/8245
# Augmented row 1079/8245
# Augmented row 1080/8245
# Augmented row 1081/8245
# Augmented row 1082/8245
# Augmented row 1083/8245
# Augmented row 1084/8245
# Augmented row 1085/8245
# Augmented row 1086/8245
# Augmented row 1087/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1088/8245
# Augmented row 1089/8245
# Augmented row 1090/8245
# Augmented row 1091/8245
# Augmented row 1092/8245
# Augmented row 1093/8245
# Augmented row 1094/8245
# Augmented row 1095/8245
# Augmented row 1096/8245
# Augmented row 1097/8245
# Augmented row 1098/8245
# Augmented row 1099/8245
# Augmented row 1100/8245
# Augmented row 1101/8245
# Augmented row 1102/8245
# Augmented row 1103/8245
# Augmented row 1104/8245
# Augmented row 1105/8245
# Augmented row 1106/8245
# Augmented row 1107/8245
# Augmented row 1108/8245
# Augmented row 1109/8245
# Augmented row 1110/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1111/8245
# Augmented row 1112/8245
# Augmented row 1113/8245
# Augmented row 1114/8245
# Augmented row 1115/8245
# Augmented row 1116/8245
# Augmented row 1117/8245
# Augmented row 1118/8245
# Augmented row 1119/8245
# Augmented row 1120/8245
# Augmented row 1121/8245
# Augmented row 1122/8245
# Augmented row 1123/8245
# Augmented row 1124/8245
# Augmented row 1125/8245
# Augmented row 1126/8245
# Augmented row 1127/8245
# Augmented row 1128/8245
# Augmented row 1129/8245
# Augmented row 1130/8245
# Augmented row 1131/8245
# Augmented row 1132/8245
# Augmented row 1133/8245
# Augmented row 1134/8245
# Augmented row 1135/8245
# Augmented row 1136/8245
# Augmented row 1137/8245
# Augmented row 1138/8245
# Augmented row 1139/8245
# Augmented row 1140/8245
# Augmented row 1141/8245
# Augmented row 1142/8245
# Augmented row 1143/8245
# Augmented row 1144/8245
# Augmented row 1145/8245
# Augmented row 1146/8245
# Augmented row 1147/8245
# Augmented row 1148/8245
# Augmented row 1149/8245
# Augmented row 1150/8245
# Augmented row 1151/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1152/8245
# Augmented row 1153/8245
# Augmented row 1154/8245
# Augmented row 1155/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1156/8245
# Augmented row 1157/8245
# Augmented row 1158/8245
# Augmented row 1159/8245
# Augmented row 1160/8245
# Augmented row 1161/8245
# Augmented row 1162/8245
# Augmented row 1163/8245
# Augmented row 1164/8245
# Augmented row 1165/8245
# Augmented row 1166/8245
# Augmented row 1167/8245
# Augmented row 1168/8245
# Augmented row 1169/8245
# Augmented row 1170/8245
# Augmented row 1171/8245
# Augmented row 1172/8245
# Augmented row 1173/8245
# Augmented row 1174/8245
# Augmented row 1175/8245
# Augmented row 1176/8245
# Augmented row 1177/8245
# Augmented row 1178/8245
# Augmented row 1179/8245
# Augmented row 1180/8245
# Augmented row 1181/8245
# Augmented row 1182/8245
# Augmented row 1183/8245
# Augmented row 1184/8245
# Augmented row 1185/8245
# Augmented row 1186/8245
# Augmented row 1187/8245
# Augmented row 1188/8245
# Augmented row 1189/8245
# Augmented row 1190/8245
# Augmented row 1191/8245
# Augmented row 1192/8245
# Augmented row 1193/8245
# Augmented row 1194/8245
# Augmented row 1195/8245
# Augmented row 1196/8245
# Augmented row 1197/8245
# Augmented row 1198/8245
# Augmented row 1199/8245
# Augmented row 1200/8245
# Augmented row 1201/8245
# Augmented row 1202/8245
# Augmented row 1203/8245
# Augmented row 1204/8245
# Augmented row 1205/8245
# Augmented row 1206/8245
# Augmented row 1207/8245
# Augmented row 1208/8245
# Augmented row 1209/8245
# Augmented row 1210/8245
# Augmented row 1211/8245
# Augmented row 1212/8245
# Augmented row 1213/8245
# Augmented row 1214/8245
# Augmented row 1215/8245
# Augmented row 1216/8245
# Augmented row 1217/8245
# Augmented row 1218/8245
# Augmented row 1219/8245
# Augmented row 1220/8245
# Augmented row 1221/8245
# Augmented row 1222/8245
# Augmented row 1223/8245
# Augmented row 1224/8245
# Augmented row 1225/8245
# Augmented row 1226/8245
# Augmented row 1227/8245
# Augmented row 1228/8245
# Augmented row 1229/8245
# Augmented row 1230/8245
# Augmented row 1231/8245
# Augmented row 1232/8245
# Augmented row 1233/8245
# Augmented row 1234/8245
# Augmented row 1235/8245
# Augmented row 1236/8245
# Augmented row 1237/8245
# Augmented row 1238/8245
# Augmented row 1239/8245
# Augmented row 1240/8245
# Augmented row 1241/8245
# Augmented row 1242/8245
# Augmented row 1243/8245
# Augmented row 1244/8245
# Augmented row 1245/8245
# Augmented row 1246/8245
# Augmented row 1247/8245
# Augmented row 1248/8245
# Augmented row 1249/8245
# Augmented row 1250/8245
# Augmented row 1251/8245
# Augmented row 1252/8245
# Augmented row 1253/8245
# Augmented row 1254/8245
# Augmented row 1255/8245
# Augmented row 1256/8245
# Augmented row 1257/8245
# Augmented row 1258/8245
# Augmented row 1259/8245
# Augmented row 1260/8245
# Augmented row 1261/8245
# Augmented row 1262/8245
# Augmented row 1263/8245
# Augmented row 1264/8245
# Augmented row 1265/8245
# Augmented row 1266/8245
# Augmented row 1267/8245
# Augmented row 1268/8245
# Augmented row 1269/8245
# Augmented row 1270/8245
# Augmented row 1271/8245
# Augmented row 1272/8245
# Augmented row 1273/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1274/8245
# Augmented row 1275/8245
# Augmented row 1276/8245
# Augmented row 1277/8245
# Augmented row 1278/8245
# Augmented row 1279/8245
# Augmented row 1280/8245
# Augmented row 1281/8245
# Augmented row 1282/8245
# Augmented row 1283/8245
# Augmented row 1284/8245
# Augmented row 1285/8245
# Augmented row 1286/8245
# Augmented row 1287/8245
# Augmented row 1288/8245
# Augmented row 1289/8245
# Augmented row 1290/8245
# Augmented row 1291/8245
# Augmented row 1292/8245
# Augmented row 1293/8245
# Augmented row 1294/8245
# Augmented row 1295/8245
# Augmented row 1296/8245
# Augmented row 1297/8245
# Augmented row 1298/8245
# Augmented row 1299/8245
# Augmented row 1300/8245
# Augmented row 1301/8245
# Augmented row 1302/8245
# Augmented row 1303/8245
# Augmented row 1304/8245
# Augmented row 1305/8245
# Augmented row 1306/8245
# Augmented row 1307/8245
# Augmented row 1308/8245
# Augmented row 1309/8245
# Augmented row 1310/8245
# Augmented row 1311/8245
# Augmented row 1312/8245
# Augmented row 1313/8245
# Augmented row 1314/8245
# Augmented row 1315/8245
# Augmented row 1316/8245
# Augmented row 1317/8245
# Augmented row 1318/8245
# Augmented row 1319/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1320/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1321/8245
# Augmented row 1322/8245
# Augmented row 1323/8245
# Augmented row 1324/8245
# Augmented row 1325/8245
# Augmented row 1326/8245
# Augmented row 1327/8245
# Augmented row 1328/8245
# Augmented row 1329/8245
# Augmented row 1330/8245
# Augmented row 1331/8245
# Augmented row 1332/8245
# Augmented row 1333/8245
# Augmented row 1334/8245
# Augmented row 1335/8245
# Augmented row 1336/8245
# Augmented row 1337/8245
# Augmented row 1338/8245
# Augmented row 1339/8245
# Augmented row 1340/8245
# Augmented row 1341/8245
# Augmented row 1342/8245
# Augmented row 1343/8245
# Augmented row 1344/8245
# Augmented row 1345/8245
# Augmented row 1346/8245
# Augmented row 1347/8245
# Augmented row 1348/8245
# Augmented row 1349/8245
# Augmented row 1350/8245
# Augmented row 1351/8245
# Augmented row 1352/8245
# Augmented row 1353/8245
# Augmented row 1354/8245
# Augmented row 1355/8245
# Augmented row 1356/8245
# Augmented row 1357/8245
# Augmented row 1358/8245
# Augmented row 1359/8245
# Augmented row 1360/8245
# Augmented row 1361/8245
# Augmented row 1362/8245
# Augmented row 1363/8245
# Augmented row 1364/8245
# Augmented row 1365/8245
# Augmented row 1366/8245
# Augmented row 1367/8245
# Augmented row 1368/8245
# Augmented row 1369/8245
# Augmented row 1370/8245
# Augmented row 1371/8245
# Augmented row 1372/8245
# Augmented row 1373/8245
# Augmented row 1374/8245
# Augmented row 1375/8245
# Augmented row 1376/8245
# Augmented row 1377/8245
# Augmented row 1378/8245
# Augmented row 1379/8245
# Augmented row 1380/8245
# Augmented row 1381/8245
# Augmented row 1382/8245
# Augmented row 1383/8245
# Augmented row 1384/8245
# Augmented row 1385/8245
# Augmented row 1386/8245
# Augmented row 1387/8245
# Augmented row 1388/8245
# Augmented row 1389/8245
# Augmented row 1390/8245
# Augmented row 1391/8245
# Augmented row 1392/8245
# Augmented row 1393/8245
# Augmented row 1394/8245
# Augmented row 1395/8245
# Augmented row 1396/8245
# Augmented row 1397/8245
# Augmented row 1398/8245
# Augmented row 1399/8245
# Augmented row 1400/8245
# Augmented row 1401/8245
# Augmented row 1402/8245
# Augmented row 1403/8245
# Augmented row 1404/8245
# Augmented row 1405/8245
# Augmented row 1406/8245
# Augmented row 1407/8245
# Augmented row 1408/8245
# Augmented row 1409/8245
# Augmented row 1410/8245
# Augmented row 1411/8245
# Augmented row 1412/8245
# Augmented row 1413/8245
# Augmented row 1414/8245
# Augmented row 1415/8245
# Augmented row 1416/8245
# Augmented row 1417/8245
# Augmented row 1418/8245
# Augmented row 1419/8245
# Augmented row 1420/8245
# Augmented row 1421/8245
# Augmented row 1422/8245
# Augmented row 1423/8245
# Augmented row 1424/8245
# Augmented row 1425/8245
# Augmented row 1426/8245
# Augmented row 1427/8245
# Augmented row 1428/8245
# Augmented row 1429/8245
# Augmented row 1430/8245
# Augmented row 1431/8245
# Augmented row 1432/8245
# Augmented row 1433/8245
# Augmented row 1434/8245
# Augmented row 1435/8245
# Augmented row 1436/8245
# Augmented row 1437/8245
# Augmented row 1438/8245
# Augmented row 1439/8245
# Augmented row 1440/8245
# Augmented row 1441/8245
# Augmented row 1442/8245
# Augmented row 1443/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1444/8245
# Augmented row 1445/8245
# Augmented row 1446/8245
# Augmented row 1447/8245
# Augmented row 1448/8245
# Augmented row 1449/8245
# Augmented row 1450/8245
# Augmented row 1451/8245
# Augmented row 1452/8245
# Augmented row 1453/8245
# Augmented row 1454/8245
# Augmented row 1455/8245
# Augmented row 1456/8245
# Augmented row 1457/8245
# Augmented row 1458/8245
# Augmented row 1459/8245
# Augmented row 1460/8245
# Augmented row 1461/8245
# Augmented row 1462/8245
# Augmented row 1463/8245
# Augmented row 1464/8245
# Augmented row 1465/8245
# Augmented row 1466/8245
# Augmented row 1467/8245
# Augmented row 1468/8245
# Augmented row 1469/8245
# Augmented row 1470/8245
# Augmented row 1471/8245
# Augmented row 1472/8245
# Augmented row 1473/8245
# Augmented row 1474/8245
# Augmented row 1475/8245
# Augmented row 1476/8245
# Augmented row 1477/8245
# Augmented row 1478/8245
# Augmented row 1479/8245
# Augmented row 1480/8245
# Augmented row 1481/8245
# Augmented row 1482/8245
# Augmented row 1483/8245
# Augmented row 1484/8245
# Augmented row 1485/8245
# Augmented row 1486/8245
# Augmented row 1487/8245
# Augmented row 1488/8245
# Augmented row 1489/8245
# Augmented row 1490/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1491/8245
# Augmented row 1492/8245
# Augmented row 1493/8245
# Augmented row 1494/8245
# Augmented row 1495/8245
# Augmented row 1496/8245
# Augmented row 1497/8245
# Augmented row 1498/8245
# Augmented row 1499/8245
# Augmented row 1500/8245
# Augmented row 1501/8245
# Augmented row 1502/8245
# Augmented row 1503/8245
# Augmented row 1504/8245
# Augmented row 1505/8245
# Augmented row 1506/8245
# Augmented row 1507/8245
# Augmented row 1508/8245
# Augmented row 1509/8245
# Augmented row 1510/8245
# Augmented row 1511/8245
# Augmented row 1512/8245
# Augmented row 1513/8245
# Augmented row 1514/8245
# Augmented row 1515/8245
# Augmented row 1516/8245
# Augmented row 1517/8245
# Augmented row 1518/8245
# Augmented row 1519/8245
# Augmented row 1520/8245
# Augmented row 1521/8245
# Augmented row 1522/8245
# Augmented row 1523/8245
# Augmented row 1524/8245
# Augmented row 1525/8245
# Augmented row 1526/8245
# Augmented row 1527/8245
# Augmented row 1528/8245
# Augmented row 1529/8245
# Augmented row 1530/8245
# Augmented row 1531/8245
# Augmented row 1532/8245
# Augmented row 1533/8245
# Augmented row 1534/8245
# Augmented row 1535/8245
# Augmented row 1536/8245
# Augmented row 1537/8245
# Augmented row 1538/8245
# Augmented row 1539/8245
# Augmented row 1540/8245
# Augmented row 1541/8245
# Augmented row 1542/8245
# Augmented row 1543/8245
# Augmented row 1544/8245
# Augmented row 1545/8245
# Augmented row 1546/8245
# Augmented row 1547/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1548/8245
# Augmented row 1549/8245
# Augmented row 1550/8245
# Augmented row 1551/8245
# Augmented row 1552/8245
# Augmented row 1553/8245
# Augmented row 1554/8245
# Augmented row 1555/8245
# Augmented row 1556/8245
# Augmented row 1557/8245
# Augmented row 1558/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Not enough words to perform swap.
# Augmented row 1559/8245
# Augmented row 1560/8245
# Augmented row 1561/8245
# Augmented row 1562/8245
# Augmented row 1563/8245
# Augmented row 1564/8245
# Augmented row 1565/8245
# Augmented row 1566/8245
# Augmented row 1567/8245
# Augmented row 1568/8245
# Augmented row 1569/8245
# Augmented row 1570/8245
# Augmented row 1571/8245
# Augmented row 1572/8245
# Augmented row 1573/8245
# Augmented row 1574/8245
# Augmented row 1575/8245
# Augmented row 1576/8245
# Augmented row 1577/8245
# Augmented row 1578/8245
# Augmented row 1579/8245
# Augmented row 1580/8245
# Augmented row 1581/8245
# Augmented row 1582/8245
# Augmented row 1583/8245
# Augmented row 1584/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1585/8245
# Augmented row 1586/8245
# Augmented row 1587/8245
# Augmented row 1588/8245
# Augmented row 1589/8245
# Augmented row 1590/8245
# Augmented row 1591/8245
# Augmented row 1592/8245
# Augmented row 1593/8245
# Augmented row 1594/8245
# Augmented row 1595/8245
# Augmented row 1596/8245
# Augmented row 1597/8245
# Augmented row 1598/8245
# Augmented row 1599/8245
# Augmented row 1600/8245
# Augmented row 1601/8245
# Augmented row 1602/8245
# Augmented row 1603/8245
# Augmented row 1604/8245
# Augmented row 1605/8245
# Augmented row 1606/8245
# Augmented row 1607/8245
# Augmented row 1608/8245
# Augmented row 1609/8245
# Augmented row 1610/8245
# Augmented row 1611/8245
# Augmented row 1612/8245
# Augmented row 1613/8245
# Augmented row 1614/8245
# Augmented row 1615/8245
# Augmented row 1616/8245
# Augmented row 1617/8245
# Augmented row 1618/8245
# Augmented row 1619/8245
# Augmented row 1620/8245
# Augmented row 1621/8245
# Augmented row 1622/8245
# Augmented row 1623/8245
# Augmented row 1624/8245
# Augmented row 1625/8245
# Augmented row 1626/8245
# Augmented row 1627/8245
# Augmented row 1628/8245
# Augmented row 1629/8245
# Augmented row 1630/8245
# Augmented row 1631/8245
# Augmented row 1632/8245
# Augmented row 1633/8245
# Augmented row 1634/8245
# Augmented row 1635/8245
# Augmented row 1636/8245
# Augmented row 1637/8245
# Augmented row 1638/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1639/8245
# Augmented row 1640/8245
# Augmented row 1641/8245
# Augmented row 1642/8245
# Augmented row 1643/8245
# Augmented row 1644/8245
# Augmented row 1645/8245
# Augmented row 1646/8245
# Augmented row 1647/8245
# Augmented row 1648/8245
# Augmented row 1649/8245
# Augmented row 1650/8245
# Augmented row 1651/8245
# Augmented row 1652/8245
# Augmented row 1653/8245
# Augmented row 1654/8245
# Augmented row 1655/8245
# Augmented row 1656/8245
# Augmented row 1657/8245
# Augmented row 1658/8245
# Augmented row 1659/8245
# Augmented row 1660/8245
# Augmented row 1661/8245
# Augmented row 1662/8245
# Augmented row 1663/8245
# Augmented row 1664/8245
# Augmented row 1665/8245
# Augmented row 1666/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1667/8245
# Augmented row 1668/8245
# Augmented row 1669/8245
# Augmented row 1670/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1671/8245
# Augmented row 1672/8245
# Augmented row 1673/8245
# Augmented row 1674/8245
# Augmented row 1675/8245
# Augmented row 1676/8245
# Augmented row 1677/8245
# Augmented row 1678/8245
# Augmented row 1679/8245
# Augmented row 1680/8245
# Augmented row 1681/8245
# Augmented row 1682/8245
# Augmented row 1683/8245
# Augmented row 1684/8245
# Augmented row 1685/8245
# Augmented row 1686/8245
# Augmented row 1687/8245
# Augmented row 1688/8245
# Augmented row 1689/8245
# Augmented row 1690/8245
# Augmented row 1691/8245
# Augmented row 1692/8245
# Augmented row 1693/8245
# Augmented row 1694/8245
# Augmented row 1695/8245
# Augmented row 1696/8245
# Augmented row 1697/8245
# Augmented row 1698/8245
# Augmented row 1699/8245
# Augmented row 1700/8245
# Augmented row 1701/8245
# Augmented row 1702/8245
# Augmented row 1703/8245
# Augmented row 1704/8245
# Augmented row 1705/8245
# Augmented row 1706/8245
# Augmented row 1707/8245
# Augmented row 1708/8245
# Augmented row 1709/8245
# Augmented row 1710/8245
# Augmented row 1711/8245
# Augmented row 1712/8245
# Augmented row 1713/8245
# Augmented row 1714/8245
# Augmented row 1715/8245
# Augmented row 1716/8245
# Augmented row 1717/8245
# Augmented row 1718/8245
# Augmented row 1719/8245
# Augmented row 1720/8245
# Augmented row 1721/8245
# Augmented row 1722/8245
# Augmented row 1723/8245
# Augmented row 1724/8245
# Augmented row 1725/8245
# Augmented row 1726/8245
# Augmented row 1727/8245
# Augmented row 1728/8245
# Augmented row 1729/8245
# Augmented row 1730/8245
# Augmented row 1731/8245
# Augmented row 1732/8245
# Augmented row 1733/8245
# Augmented row 1734/8245
# Augmented row 1735/8245
# Augmented row 1736/8245
# Augmented row 1737/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1738/8245
# Augmented row 1739/8245
# Augmented row 1740/8245
# Augmented row 1741/8245
# Augmented row 1742/8245
# Augmented row 1743/8245
# Augmented row 1744/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1745/8245
# Augmented row 1746/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1747/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1748/8245
# Augmented row 1749/8245
# Augmented row 1750/8245
# Augmented row 1751/8245
# Augmented row 1752/8245
# Augmented row 1753/8245
# Augmented row 1754/8245
# Augmented row 1755/8245
# Augmented row 1756/8245
# Augmented row 1757/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1758/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1759/8245
# Augmented row 1760/8245
# Augmented row 1761/8245
# Augmented row 1762/8245
# Augmented row 1763/8245
# Augmented row 1764/8245
# Augmented row 1765/8245
# Augmented row 1766/8245
# Augmented row 1767/8245
# Augmented row 1768/8245
# Augmented row 1769/8245
# Augmented row 1770/8245
# Augmented row 1771/8245
# Augmented row 1772/8245
# Augmented row 1773/8245
# Augmented row 1774/8245
# Augmented row 1775/8245
# Augmented row 1776/8245
# Augmented row 1777/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1778/8245
# Augmented row 1779/8245
# Augmented row 1780/8245
# Augmented row 1781/8245
# Augmented row 1782/8245
# Augmented row 1783/8245
# Augmented row 1784/8245
# Augmented row 1785/8245
# Augmented row 1786/8245
# Augmented row 1787/8245
# Augmented row 1788/8245
# Augmented row 1789/8245
# Augmented row 1790/8245
# Augmented row 1791/8245
# Augmented row 1792/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 1793/8245
# Augmented row 1794/8245
# Augmented row 1795/8245
# Augmented row 1796/8245
# Augmented row 1797/8245
# Augmented row 1798/8245
# Augmented row 1799/8245
# Augmented row 1800/8245
# Augmented row 1801/8245
# Augmented row 1802/8245
# Augmented row 1803/8245
# Augmented row 1804/8245
# Augmented row 1805/8245
# Augmented row 1806/8245
# Augmented row 1807/8245
# Augmented row 1808/8245
# Augmented row 1809/8245
# Augmented row 1810/8245
# Augmented row 1811/8245
# Augmented row 1812/8245
# Augmented row 1813/8245
# Augmented row 1814/8245
# Augmented row 1815/8245
# Augmented row 1816/8245
# Augmented row 1817/8245
# Augmented row 1818/8245
# Augmented row 1819/8245
# Augmented row 1820/8245
# Augmented row 1821/8245
# Augmented row 1822/8245
# Augmented row 1823/8245
# Augmented row 1824/8245
# Augmented row 1825/8245
# Augmented row 1826/8245
# Augmented row 1827/8245
# Augmented row 1828/8245
# Augmented row 1829/8245
# Augmented row 1830/8245
# Augmented row 1831/8245
# Augmented row 1832/8245
# Augmented row 1833/8245
# Augmented row 1834/8245
# Augmented row 1835/8245
# Augmented row 1836/8245
# Augmented row 1837/8245
# Augmented row 1838/8245
# Augmented row 1839/8245
# Augmented row 1840/8245
# Augmented row 1841/8245
# Augmented row 1842/8245
# Augmented row 1843/8245
# Augmented row 1844/8245
# Augmented row 1845/8245
# Augmented row 1846/8245
# Augmented row 1847/8245
# Augmented row 1848/8245
# Augmented row 1849/8245
# Augmented row 1850/8245
# ...
# Augmented row 7638/8245
# Augmented row 7639/8245
# Augmented row 7640/8245
# Augmented row 7641/8245
# Augmented row 7642/8245
# Augmented row 7643/8245
# Augmented row 7644/8245
# Augmented row 7645/8245
# Augmented row 7646/8245
# Augmented row 7647/8245
# Augmented row 7648/8245
# Augmented row 7649/8245
# Augmented row 7650/8245
# Augmented row 7651/8245
# Augmented row 7652/8245
# Augmented row 7653/8245
# Augmented row 7654/8245
# Augmented row 7655/8245
# Augmented row 7656/8245
# Augmented row 7657/8245
# Augmented row 7658/8245
# Augmented row 7659/8245
# Augmented row 7660/8245
# Augmented row 7661/8245
# Augmented row 7662/8245
# Augmented row 7663/8245
# Augmented row 7664/8245
# Augmented row 7665/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7666/8245
# Augmented row 7667/8245
# Augmented row 7668/8245
# Augmented row 7669/8245
# Augmented row 7670/8245
# Augmented row 7671/8245
# Augmented row 7672/8245
# Augmented row 7673/8245
# Augmented row 7674/8245
# Augmented row 7675/8245
# Augmented row 7676/8245
# Augmented row 7677/8245
# Augmented row 7678/8245
# Augmented row 7679/8245
# Augmented row 7680/8245
# Augmented row 7681/8245
# Augmented row 7682/8245
# Augmented row 7683/8245
# Augmented row 7684/8245
# Augmented row 7685/8245
# Augmented row 7686/8245
# Augmented row 7687/8245
# Augmented row 7688/8245
# Augmented row 7689/8245
# Augmented row 7690/8245
# Augmented row 7691/8245
# Augmented row 7692/8245
# Augmented row 7693/8245
# Augmented row 7694/8245
# Augmented row 7695/8245
# Augmented row 7696/8245
# Augmented row 7697/8245
# Augmented row 7698/8245
# Augmented row 7699/8245
# Augmented row 7700/8245
# Augmented row 7701/8245
# Augmented row 7702/8245
# Augmented row 7703/8245
# Augmented row 7704/8245
# Augmented row 7705/8245
# Augmented row 7706/8245
# Augmented row 7707/8245
# Augmented row 7708/8245
# Augmented row 7709/8245
# Augmented row 7710/8245
# Augmented row 7711/8245
# Augmented row 7712/8245
# Augmented row 7713/8245
# Augmented row 7714/8245
# Augmented row 7715/8245
# Augmented row 7716/8245
# Augmented row 7717/8245
# Augmented row 7718/8245
# Augmented row 7719/8245
# Augmented row 7720/8245
# Augmented row 7721/8245
# Augmented row 7722/8245
# Augmented row 7723/8245
# Augmented row 7724/8245
# Augmented row 7725/8245
# Augmented row 7726/8245
# Augmented row 7727/8245
# Augmented row 7728/8245
# Augmented row 7729/8245
# Augmented row 7730/8245
# Augmented row 7731/8245
# Augmented row 7732/8245
# Augmented row 7733/8245
# Augmented row 7734/8245
# Augmented row 7735/8245
# Augmented row 7736/8245
# Augmented row 7737/8245
# Augmented row 7738/8245
# Augmented row 7739/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7740/8245
# Augmented row 7741/8245
# Augmented row 7742/8245
# Augmented row 7743/8245
# Augmented row 7744/8245
# Augmented row 7745/8245
# Augmented row 7746/8245
# Augmented row 7747/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7748/8245
# Augmented row 7749/8245
# Augmented row 7750/8245
# Augmented row 7751/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7752/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7753/8245
# Augmented row 7754/8245
# Augmented row 7755/8245
# Augmented row 7756/8245
# Augmented row 7757/8245
# Augmented row 7758/8245
# Augmented row 7759/8245
# Augmented row 7760/8245
# Augmented row 7761/8245
# Augmented row 7762/8245
# Augmented row 7763/8245
# Augmented row 7764/8245
# Augmented row 7765/8245
# Augmented row 7766/8245
# Augmented row 7767/8245
# Augmented row 7768/8245
# Augmented row 7769/8245
# Augmented row 7770/8245
# Augmented row 7771/8245
# Augmented row 7772/8245
# Augmented row 7773/8245
# Augmented row 7774/8245
# Augmented row 7775/8245
# Augmented row 7776/8245
# Augmented row 7777/8245
# Augmented row 7778/8245
# Augmented row 7779/8245
# Augmented row 7780/8245
# Augmented row 7781/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7782/8245
# Augmented row 7783/8245
# Augmented row 7784/8245
# Augmented row 7785/8245
# Augmented row 7786/8245
# Augmented row 7787/8245
# Augmented row 7788/8245
# Augmented row 7789/8245
# Augmented row 7790/8245
# Augmented row 7791/8245
# Augmented row 7792/8245
# Augmented row 7793/8245
# Augmented row 7794/8245
# Augmented row 7795/8245
# Augmented row 7796/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7797/8245
# Augmented row 7798/8245
# Augmented row 7799/8245
# Augmented row 7800/8245
# Augmented row 7801/8245
# Augmented row 7802/8245
# Augmented row 7803/8245
# Augmented row 7804/8245
# Augmented row 7805/8245
# Augmented row 7806/8245
# Augmented row 7807/8245
# Augmented row 7808/8245
# Augmented row 7809/8245
# Augmented row 7810/8245
# Augmented row 7811/8245
# Augmented row 7812/8245
# Augmented row 7813/8245
# Augmented row 7814/8245
# Augmented row 7815/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7816/8245
# Augmented row 7817/8245
# Augmented row 7818/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7819/8245
# Augmented row 7820/8245
# Augmented row 7821/8245
# Augmented row 7822/8245
# Augmented row 7823/8245
# Augmented row 7824/8245
# Augmented row 7825/8245
# Augmented row 7826/8245
# Augmented row 7827/8245
# Augmented row 7828/8245
# Augmented row 7829/8245
# Augmented row 7830/8245
# Augmented row 7831/8245
# Augmented row 7832/8245
# Augmented row 7833/8245
# Augmented row 7834/8245
# Augmented row 7835/8245
# Augmented row 7836/8245
# Augmented row 7837/8245
# Augmented row 7838/8245
# Augmented row 7839/8245
# Augmented row 7840/8245
# Augmented row 7841/8245
# Augmented row 7842/8245
# Augmented row 7843/8245
# Augmented row 7844/8245
# Augmented row 7845/8245
# Augmented row 7846/8245
# Augmented row 7847/8245
# Augmented row 7848/8245
# Augmented row 7849/8245
# Augmented row 7850/8245
# Augmented row 7851/8245
# Augmented row 7852/8245
# Augmented row 7853/8245
# Augmented row 7854/8245
# Augmented row 7855/8245
# Augmented row 7856/8245
# Augmented row 7857/8245
# Augmented row 7858/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7859/8245
# Augmented row 7860/8245
# Augmented row 7861/8245
# Augmented row 7862/8245
# Augmented row 7863/8245
# Augmented row 7864/8245
# Augmented row 7865/8245
# Augmented row 7866/8245
# Augmented row 7867/8245
# Augmented row 7868/8245
# Augmented row 7869/8245
# Augmented row 7870/8245
# Augmented row 7871/8245
# Augmented row 7872/8245
# Augmented row 7873/8245
# Augmented row 7874/8245
# Augmented row 7875/8245
# Augmented row 7876/8245
# Augmented row 7877/8245
# Augmented row 7878/8245
# Augmented row 7879/8245
# Augmented row 7880/8245
# Augmented row 7881/8245
# Augmented row 7882/8245
# Augmented row 7883/8245
# Augmented row 7884/8245
# Augmented row 7885/8245
# Augmented row 7886/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7887/8245
# Augmented row 7888/8245
# Augmented row 7889/8245
# Augmented row 7890/8245
# Augmented row 7891/8245
# Augmented row 7892/8245
# Augmented row 7893/8245
# Augmented row 7894/8245
# Augmented row 7895/8245
# Augmented row 7896/8245
# Augmented row 7897/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7898/8245
# Augmented row 7899/8245
# Augmented row 7900/8245
# Augmented row 7901/8245
# Augmented row 7902/8245
# Augmented row 7903/8245
# Augmented row 7904/8245
# Augmented row 7905/8245
# Augmented row 7906/8245
# Augmented row 7907/8245
# Augmented row 7908/8245
# Augmented row 7909/8245
# Augmented row 7910/8245
# Augmented row 7911/8245
# Augmented row 7912/8245
# Augmented row 7913/8245
# Augmented row 7914/8245
# Augmented row 7915/8245
# Augmented row 7916/8245
# Augmented row 7917/8245
# Augmented row 7918/8245
# Augmented row 7919/8245
# Augmented row 7920/8245
# Augmented row 7921/8245
# Augmented row 7922/8245
# Augmented row 7923/8245
# Augmented row 7924/8245
# Augmented row 7925/8245
# Augmented row 7926/8245
# Augmented row 7927/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7928/8245
# Augmented row 7929/8245
# Augmented row 7930/8245
# Augmented row 7931/8245
# Augmented row 7932/8245
# Augmented row 7933/8245
# Augmented row 7934/8245
# Augmented row 7935/8245
# Augmented row 7936/8245
# Augmented row 7937/8245
# Augmented row 7938/8245
# Augmented row 7939/8245
# Augmented row 7940/8245
# Augmented row 7941/8245
# Augmented row 7942/8245
# Augmented row 7943/8245
# Augmented row 7944/8245
# Augmented row 7945/8245
# Augmented row 7946/8245
# Augmented row 7947/8245
# Augmented row 7948/8245
# Augmented row 7949/8245
# Failed to find a synonym for insertion after 10 attempts.
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7950/8245
# Augmented row 7951/8245
# Augmented row 7952/8245
# Augmented row 7953/8245
# Augmented row 7954/8245
# Augmented row 7955/8245
# Augmented row 7956/8245
# Augmented row 7957/8245
# Augmented row 7958/8245
# Augmented row 7959/8245
# Augmented row 7960/8245
# Augmented row 7961/8245
# Augmented row 7962/8245
# Augmented row 7963/8245
# Augmented row 7964/8245
# Augmented row 7965/8245
# Augmented row 7966/8245
# Augmented row 7967/8245
# Augmented row 7968/8245
# Augmented row 7969/8245
# Augmented row 7970/8245
# Augmented row 7971/8245
# Augmented row 7972/8245
# Augmented row 7973/8245
# Augmented row 7974/8245
# Augmented row 7975/8245
# Augmented row 7976/8245
# Augmented row 7977/8245
# Augmented row 7978/8245
# Augmented row 7979/8245
# Augmented row 7980/8245
# Augmented row 7981/8245
# Augmented row 7982/8245
# Augmented row 7983/8245
# Augmented row 7984/8245
# Augmented row 7985/8245
# Augmented row 7986/8245
# Augmented row 7987/8245
# Augmented row 7988/8245
# Augmented row 7989/8245
# Augmented row 7990/8245
# Augmented row 7991/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 7992/8245
# Augmented row 7993/8245
# Augmented row 7994/8245
# Augmented row 7995/8245
# Augmented row 7996/8245
# Augmented row 7997/8245
# Augmented row 7998/8245
# Augmented row 7999/8245
# Augmented row 8000/8245
# Augmented row 8001/8245
# Augmented row 8002/8245
# Augmented row 8003/8245
# Augmented row 8004/8245
# Augmented row 8005/8245
# Augmented row 8006/8245
# Augmented row 8007/8245
# Augmented row 8008/8245
# Augmented row 8009/8245
# Augmented row 8010/8245
# Augmented row 8011/8245
# Augmented row 8012/8245
# Augmented row 8013/8245
# Augmented row 8014/8245
# Augmented row 8015/8245
# Augmented row 8016/8245
# Augmented row 8017/8245
# Augmented row 8018/8245
# Augmented row 8019/8245
# Augmented row 8020/8245
# Augmented row 8021/8245
# Augmented row 8022/8245
# Augmented row 8023/8245
# Augmented row 8024/8245
# Augmented row 8025/8245
# Augmented row 8026/8245
# Augmented row 8027/8245
# Augmented row 8028/8245
# Augmented row 8029/8245
# Augmented row 8030/8245
# Augmented row 8031/8245
# Augmented row 8032/8245
# Augmented row 8033/8245
# Augmented row 8034/8245
# Augmented row 8035/8245
# Augmented row 8036/8245
# Augmented row 8037/8245
# Augmented row 8038/8245
# Augmented row 8039/8245
# Augmented row 8040/8245
# Augmented row 8041/8245
# Augmented row 8042/8245
# Augmented row 8043/8245
# Augmented row 8044/8245
# Augmented row 8045/8245
# Augmented row 8046/8245
# Augmented row 8047/8245
# Augmented row 8048/8245
# Augmented row 8049/8245
# Augmented row 8050/8245
# Augmented row 8051/8245
# Augmented row 8052/8245
# Augmented row 8053/8245
# Augmented row 8054/8245
# Augmented row 8055/8245
# Augmented row 8056/8245
# Augmented row 8057/8245
# Augmented row 8058/8245
# Augmented row 8059/8245
# Augmented row 8060/8245
# Augmented row 8061/8245
# Augmented row 8062/8245
# Augmented row 8063/8245
# Augmented row 8064/8245
# Augmented row 8065/8245
# Augmented row 8066/8245
# Augmented row 8067/8245
# Augmented row 8068/8245
# Augmented row 8069/8245
# Augmented row 8070/8245
# Augmented row 8071/8245
# Augmented row 8072/8245
# Augmented row 8073/8245
# Augmented row 8074/8245
# Augmented row 8075/8245
# Augmented row 8076/8245
# Augmented row 8077/8245
# Augmented row 8078/8245
# Augmented row 8079/8245
# Augmented row 8080/8245
# Augmented row 8081/8245
# Augmented row 8082/8245
# Augmented row 8083/8245
# Augmented row 8084/8245
# Augmented row 8085/8245
# Augmented row 8086/8245
# Augmented row 8087/8245
# Augmented row 8088/8245
# Augmented row 8089/8245
# Augmented row 8090/8245
# Augmented row 8091/8245
# Augmented row 8092/8245
# Augmented row 8093/8245
# Augmented row 8094/8245
# Augmented row 8095/8245
# Augmented row 8096/8245
# Augmented row 8097/8245
# Augmented row 8098/8245
# Augmented row 8099/8245
# Augmented row 8100/8245
# Augmented row 8101/8245
# Augmented row 8102/8245
# Augmented row 8103/8245
# Augmented row 8104/8245
# Augmented row 8105/8245
# Augmented row 8106/8245
# Augmented row 8107/8245
# Augmented row 8108/8245
# Augmented row 8109/8245
# Augmented row 8110/8245
# Augmented row 8111/8245
# Augmented row 8112/8245
# Augmented row 8113/8245
# Augmented row 8114/8245
# Augmented row 8115/8245
# Augmented row 8116/8245
# Augmented row 8117/8245
# Augmented row 8118/8245
# Augmented row 8119/8245
# Augmented row 8120/8245
# Augmented row 8121/8245
# Augmented row 8122/8245
# Augmented row 8123/8245
# Augmented row 8124/8245
# Augmented row 8125/8245
# Augmented row 8126/8245
# Augmented row 8127/8245
# Augmented row 8128/8245
# Augmented row 8129/8245
# Augmented row 8130/8245
# Augmented row 8131/8245
# Augmented row 8132/8245
# Augmented row 8133/8245
# Augmented row 8134/8245
# Augmented row 8135/8245
# Augmented row 8136/8245
# Augmented row 8137/8245
# Augmented row 8138/8245
# Augmented row 8139/8245
# Augmented row 8140/8245
# Augmented row 8141/8245
# Augmented row 8142/8245
# Augmented row 8143/8245
# Augmented row 8144/8245
# Augmented row 8145/8245
# Augmented row 8146/8245
# Augmented row 8147/8245
# Augmented row 8148/8245
# Augmented row 8149/8245
# Augmented row 8150/8245
# Augmented row 8151/8245
# Augmented row 8152/8245
# Augmented row 8153/8245
# Augmented row 8154/8245
# Augmented row 8155/8245
# Augmented row 8156/8245
# Augmented row 8157/8245
# Augmented row 8158/8245
# Augmented row 8159/8245
# Augmented row 8160/8245
# Augmented row 8161/8245
# Augmented row 8162/8245
# Augmented row 8163/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 8164/8245
# Augmented row 8165/8245
# Augmented row 8166/8245
# Augmented row 8167/8245
# Augmented row 8168/8245
# Augmented row 8169/8245
# Augmented row 8170/8245
# Augmented row 8171/8245
# Augmented row 8172/8245
# Augmented row 8173/8245
# Augmented row 8174/8245
# Augmented row 8175/8245
# Augmented row 8176/8245
# Augmented row 8177/8245
# Augmented row 8178/8245
# Augmented row 8179/8245
# Augmented row 8180/8245
# Augmented row 8181/8245
# Augmented row 8182/8245
# Augmented row 8183/8245
# Augmented row 8184/8245
# Augmented row 8185/8245
# Augmented row 8186/8245
# Augmented row 8187/8245
# Augmented row 8188/8245
# Augmented row 8189/8245
# Augmented row 8190/8245
# Augmented row 8191/8245
# Augmented row 8192/8245
# Augmented row 8193/8245
# Augmented row 8194/8245
# Augmented row 8195/8245
# Augmented row 8196/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 8197/8245
# Augmented row 8198/8245
# Augmented row 8199/8245
# Augmented row 8200/8245
# Augmented row 8201/8245
# Augmented row 8202/8245
# Augmented row 8203/8245
# Augmented row 8204/8245
# Augmented row 8205/8245
# Augmented row 8206/8245
# Augmented row 8207/8245
# Augmented row 8208/8245
# Augmented row 8209/8245
# Augmented row 8210/8245
# Augmented row 8211/8245
# Augmented row 8212/8245
# Augmented row 8213/8245
# Augmented row 8214/8245
# Augmented row 8215/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 8216/8245
# Augmented row 8217/8245
# Augmented row 8218/8245
# Augmented row 8219/8245
# Augmented row 8220/8245
# Augmented row 8221/8245
# Augmented row 8222/8245
# Augmented row 8223/8245
# Augmented row 8224/8245
# Augmented row 8225/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 8226/8245
# Augmented row 8227/8245
# Failed to find a synonym for insertion after 10 attempts.
# Augmented row 8228/8245
# Augmented row 8229/8245
# Augmented row 8230/8245
# Augmented row 8231/8245
# Augmented row 8232/8245
# Augmented row 8233/8245
# Augmented row 8234/8245
# Augmented row 8235/8245
# Augmented row 8236/8245
# Augmented row 8237/8245
# Augmented row 8238/8245
# Augmented row 8239/8245
# Augmented row 8240/8245
# Augmented row 8241/8245
# Augmented row 8242/8245
# Augmented row 8243/8245
# Augmented row 8244/8245
# Augmented row 8245/8245
# Augmentation complete. The augmented dataset has been saved.
